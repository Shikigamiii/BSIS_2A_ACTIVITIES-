# %% [markdown]
# <a href="https://colab.research.google.com/github/Shikigamiii/BSIS_2A_ACTIVITIES-/blob/main/Las_igan_Mcgyver_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Shikigamiii/BSIS_2A_ACTIVITIES-/main/RailsToTrails_National%20Count%20Data_week.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Timeframe                   52 non-null     object
#  1   Week of                     52 non-null     object
#  2    2019 counts (31 counters)  52 non-null     int64
#  3    2020 counts (31 counters)  52 non-null     int64
#  4   2021 Counts                 0 non-null      float64
#  5   Change 2019-2020            52 non-null     object
#  6   Unnamed: 6                  52 non-null     float64
#  7   Unnamed: 7                  0 non-null      float64
#  8   Unnamed: 8                  1 non-null      object
#  9   Unnamed: 9                  1 non-null      float64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 4.2+ KB

# %%
df.head()
# Out:
#   Timeframe Week of   2019 counts (31 counters)   2020 counts (31 counters)  \
# 0    Week 1  30-Dec                      167679                      183546
# 1    Week 2   6-Jan                       82340                       97140
# 2    Week 3  13-Jan                       62315                       75782
# 3    Week 4  20-Jan                       75801                       83809
# 4    Week 5  27-Jan                       75841                       94738
#
#    2021 Counts Change 2019-2020  Unnamed: 6  Unnamed: 7 Unnamed: 8  Unnamed: 9
# 0          NaN               9%    1.094627         NaN        NaN         NaN
# 1          NaN              18%  117.974253         NaN        NaN         NaN
# 2          NaN              22%  121.611169         NaN        NaN         NaN
# 3          NaN              11%  110.564504         NaN        NaN         NaN
# 4          NaN              25%  124.916602         NaN        NaN         NaN

# %%
df = df.drop(columns=['Unnamed: 7','Unnamed: 8','Unnamed: 9'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Timeframe                   52 non-null     object
#  1   Week of                     52 non-null     object
#  2    2019 counts (31 counters)  52 non-null     int64
#  3    2020 counts (31 counters)  52 non-null     int64
#  4   2021 Counts                 0 non-null      float64
#  5   Change 2019-2020            52 non-null     object
#  6   percent_change              52 non-null     float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 3.0+ KB

# %%
df = df.rename(columns={'Unnamed: 6': 'percent_change'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Timeframe                   52 non-null     object
#  1   Week of                     52 non-null     object
#  2    2019 counts (31 counters)  52 non-null     int64
#  3    2020 counts (31 counters)  52 non-null     int64
#  4   2021 Counts                 0 non-null      float64
#  5   Change 2019-2020            52 non-null     object
#  6   percent_change              52 non-null     float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 3.0+ KB

# %%
df.isna()
# Out:
#     Timeframe  Week of   2019 counts (31 counters)  \
# 0       False    False                       False
# 1       False    False                       False
# 2       False    False                       False
# 3       False    False                       False
# 4       False    False                       False
# 5       False    False                       False
# 6       False    False                       False
# 7       False    False                       False
# 8       False    False                       False
# 9       False    False                       False
# 10      False    False                       False
# 11      False    False                       False
# 12      False    False                       False
# 13      False    False                       False
# 14      False    False                       False
# 15      False    False                       False
# 16      False    False                       False
# ...

# %%
df.isna().sum()
# Out:
# Timeframe                      0
# Week of                        0
#  2019 counts (31 counters)     0
#  2020 counts (31 counters)     0
# 2021 Counts                   52
# Change 2019-2020               0
# percent_change                 0
# dtype: int64

# %%
df['2021 Counts'].fillna('missing', inplace=True)

# %%
df.isna().sum()
# Out:
# Timeframe                     0
# Week of                       0
#  2019 counts (31 counters)    0
#  2020 counts (31 counters)    0
# 2021 Counts                   0
# Change 2019-2020              0
# percent_change                0
# dtype: int64

# %%
df = df.rename(columns={' 2019 counts (31 counters)': 'counts_2019 (12 Pogime)'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Timeframe                   52 non-null     object
#  1   Week of                     52 non-null     object
#  2   counts_2019 (12 Pogime)     52 non-null     int64
#  3    2020 counts (31 counters)  52 non-null     int64
#  4   2021 Counts                 52 non-null     object
#  5   Change 2019-2020            52 non-null     object
#  6   percent_change              52 non-null     float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 3.0+ KB
